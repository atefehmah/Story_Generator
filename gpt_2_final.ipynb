# %% [markdown]
# # GPT-2 Final
#
# ### My Idea
# I was planing to tell stories about single images based on spesific courpeses. However I became familiar with GPT-2 language model.GPT-2 is a large transformer-based language model which was published this February by OpenAI. the objective of this model is to predict the next word, given all of the previous words within some text.  So I decided to use this language model to generate stories.
#
# I can generate stories for a single image. However I decided to go with the sequence of images instead. I found a paper "Stories for Images-in-Sequence by using Visual and Narrative Components" that explores generating captions based on a sequence of images. So each caption at the same time is related to the image itself and the previous caption.
#
#
# ## Steps
#
# ###1. Installation
# Clone the repo, install dependencies, and download the model weights.
#
# You can choose between the small 117M, medium 345M, large 774M model, xl 1.5B model or all of them.
# You should enter the prompts into the prompt box that apears after running the model.

# %%
# !git clone https://github.com/ilopezfr/gpt-2/
import os
os.chdir('gpt-2')
# !python download_model.py 117M
# !python download_model.py 345M
# !python download_model.py 774M
# !python download_model.py 1558M
# !pip3 install -r requirements.txt
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 310, done.
# remote: Total 310 (delta 0), reused 0 (delta 0), pack-reused 310
# Receiving objects: 100% (310/310), 4.63 MiB | 6.54 MiB/s, done.
# Resolving deltas: 100% (174/174), done.
# Fetching checkpoint: 1.00kit [00:00, 880kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 38.9Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 862kit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:27, 51.6Mit/s]
# Fetching model.ckpt.index: 11.0kit [00:00, 6.09Mit/s]
# Fetching model.ckpt.meta: 927kit [00:00, 40.1Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 28.0Mit/s]
# ...
#      |████████████████████████████████| 81kB 4.6MB/s
# ...
#      |████████████████████████████████| 614kB 19.0MB/s
# ...
#      |████████████████████████████████| 51kB 7.0MB/s
# ...
#   Created wheel for fire: filename=fire-0.2.1-py2.py3-none-any.whl size=103527 sha256=9b8a2fac570d3a7b32d80e2a69a329a391867da1e5d5aa9e304fb20bc464ac8a
# ...

# %% [markdown]
# ## Conditional sample generation
#
# To generate conditional samples from the small model:
# ```
# !python3 src/interactive_conditional_samples.py
# ```
# It comes with a few flags available, with a default value:
# -  `model_name = '117M' ` : choose between 117M and 345M models. By default is 117M.
# - `seed = None`  || a random value is generated unless specified. give a specific integer value if you want to reproduce same results in the future.
# - `nsamples = 1`     ||  specify the number of samples you want to print
# - `length = None`   ||  number of tokens (words) to print on each sample.
# - `batch_size= 1`  ||  how many inputs you want to process simultaneously. *only affects speed/memory*
# - `temperature = 1`  ||  float between 0 and 1. scales logits before sampling prior to softmax. higher temperature results in more random completions.
# - `top_k = 0`   ||  Integer value controlling diversity.  Truncates the set of logits considered to those with the highest values. 1 means only 1 word is considered for each step (token), resulting in deterministic completions. 40 means 40 words are considered at each step. 0 (default) is a special setting meaning no restrictions. 40 generally is a good value.
#
#
#
# The authors tested the model performance on a few different language tasks, including **reading comprehension, text completion, summarization, translation, and question-answering.**
#
# Below are a few examples selected to test the aforementioned behaviors:

# %% [markdown]
# ### Run the other notebook to get the prompts to feed the gpt2 model

# %%
#Run the other notebook to get the prompts to feed the gpt2 model
# %run ./get_prompts.ipynb
# Out:
# here
# sis's [train] loaded. It took 1.53 seconds.
# here val
# sis's [val] loaded. It took 0.17 seconds.
# here test
# sis's [test] loaded. It took 0.26 seconds.
# Make mapping ...
# Mapping for [Albums][Images][Stories][Sents] done.

# %%
for i,prompt in enumerate(prompts):
    print("")
    print("PROMPT "+ str(i))
    print(prompt)
    print("")
# Out:
# PROMPT 0
# our landmark tree in town was about to be destroyed and cleared for a new mall .so we decided to take the day to go out and enjoy its beauty .to see the final glimpse of the roots , extending out into the depths of the hill .and its magnificent trunk , larger than life itself .one last picture of its beauty so we could capture it forever .
#
#
# PROMPT 1
# our trip to location last year was filled with beauty . sculptures could be found everywhere we went .the architecture was old and interesting .since it was spring , beautiful flowers lined the streets . this pink bloom was particularly lovely .we went to a museum and saw this odd collection of hanging faces !i 'd have to say my favorite part of the trip would have to be the food though . we ca n't wait to go back again !
#
#
# PROMPT 2
# ...

# %% [markdown]
# ### 1. Text Completion
#
# - Context: random unseen text
#
# Sample prompt 1 (This is from the single image captioning file):
# ```
# a horse driven carriage running through the rainstorm
# ```
#
# Sample prompt 2:
#
# ```
# our landmark tree in town was about to be destroyed and cleared for a new mall .so we decided to take the day to go out and enjoy its beauty .to see the final glimpse of the roots , extending out into the depths of the hill .and its magnificent trunk , larger than life itself .one last picture of its beauty so we could capture it forever .
# ```
#
# Sample prompt 3:
# ```
# our trip to location last year was filled with beauty . sculptures could be found everywhere we went .the architecture was old and interesting .since it was spring , beautiful flowers lined the streets . this pink bloom was particularly lovely .we went to a museum and saw this odd collection of hanging faces !i 'd have to say my favorite part of the trip would have to be the food though . we ca n't wait to go back again !
# ```
#
# Sample prompt 4:
# ```
# the city in 1940 decided to build a water dam .over 100 's of construction trucks .the city dam was used to generate power to the city .the construction workers began leveling the ground for the water dam .water pumps were used to control the water flow of the dam .
# ```
# Sample prompt 5:
# ```
# my father visited location for the summer .he visited a small temple .he encountered many great people on his visit .a few of the individuals he took pictures of were camera shy .inside the temple you could see the beautiful hand carved and painted murals .
# ```
# Sample prompt 6:
# ```
# the couple took a picture .his wife was pregnant .they took a silly picture .they later went on a hike .they got a picture of her behind a mountain .
# ```
# Sample prompt 7:
# ```
# the family celebrated our 2 year old birthday .our 2 year old is a [female] baby .we rented a fun house to jump in .our eldest daughter did n't seem to get tired .the loving man in our lives reminded us of the importance of family .
# ```

# %%
# !python3 src/interactive_conditional_samples.py --model_name='345M' --nsamples=2 --length=100 --top_k=80 --temperature=.80
# Out:
# WARNING:tensorflow:From src/interactive_conditional_samples.py:57: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-02 02:07:40.144614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-02 02:07:40.165337: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-02 02:07:40.166118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-12-02 02:07:40.166449: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python3 src/interactive_conditional_samples.py --model_name='345M'  --nsamples=2 --top_k=100 --temperature=1
# Out:
# 2019-05-17 01:10:52.485283: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-17 01:10:52.485488: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2118680 executing computations on platform Host. Devices:
# 2019-05-17 01:10:52.485519: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-17 01:10:52.643805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-17 01:10:52.644315: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2117fa0 executing computations on platform CUDA. Devices:
# 2019-05-17 01:10:52.644346: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...

# %% [markdown]
# ### Results (stories)
#
# The results are chopped of because I limited the length of generated text.
#
# Sample cation from a sequence of images.
#
# ![title](img/picture.png)
#
#
#
# #####################################################################################################################
#
# #### Generated Captions from the sequence of images:
#
# ```
# Delicious Thai dishes started with some crispy chicken. pad thai is always one of my favorites. this dish featured sprouts and veggies. this one was crispy and very tasty. this was a simple dish with veggies sliced thin. my favorite!
# ```
# #### First model (--model_name='345M' --nsamples=2 --length=100 --top_k=40 --temperature=.80)
#
# ======================================== SAMPLE 1 ========================================
#
#
# I'm always looking for ways to improve my Thai food. My favorite is Pad Thai. It's usually one of my favorites when it comes to dishes. If you are looking for some of the best Thai food in LA with great results, try this place! It's cheap, you can eat there in about 3 minutes and they have some of the best Thai food in the city. They serve Thai food in a casual atmosphere with no wait. I can't wait to try all their restaurants
#
# ======================================== SAMPLE 2 ========================================
#
#
# This is a pretty decent place. I'm a huge fan of Thai food from my Thai parents. I've tried a lot of Thai food in the area and this place definitely has the food to back it up. My favorite thing about this place is that they have a large selection of Thai dishes. My favorite dish is the pad thai. It's crispy on the outside, chewy on the inside. It's sweet and spicy on the outside, but it's really good in the
#
# ================================================================================
#
#
#
# #### Second model (--model_name='345M'  --nsamples=2 --length=100 --top_k=100 --temperature=1)
#
# ======================================== SAMPLE 1 ========================================
#
#  one of my favorite bites. my boyfriend had a bowl of chicken with coconut rice with a pile of meat. and with the curry sauce on chicken, it had that smoky meat to it. this dish was very good. i loved the curry sauce on this dish, but for me it was more smoky. my boyfriend really loved this dish. he was amazed with the chicken i added to it. this dish, though a little too simple, was certainly better than most of his dishes, because
#
# ======================================== SAMPLE 2 ========================================
#
#
# I've been craving such a Thai dish ever since waking up Wednesday morning! I've tried several different dishes over the last few years and these really knock them out of the park. The flavor was strong & the pan fried chicken and noodles were amazing & very tasty. This was probably my favorite Thai meal out of the six. The chicken, noodles & sweet & sour sauce were all top notch and so had on an island with a green island view and beautiful beach.
#
#
# ### The following are generated samples from the above promts. This resuls can also be found under the model cell.
#
# Model prompt >>> a horse driven carriage running through the rainstorm
# 2019-12-02 02:08:08.885026: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
#
# ======================================== SAMPLE 1 ========================================
# . It was a chance encounter, and I was about to let my guard down and let in a few insects on their way out when a big bear was snoozing on my shoulder. I was too busy getting ready to fight the damn thing to check his mouth, so I let him enjoy his nap. But when I took it off, I realized that he was not sleeping soundly, and I was getting pretty tired. So I took off to find a safe place to rest. The bear
#
# ======================================== SAMPLE 2 ========================================
#  for its ride back to the village.
#
# This was the scene from the day she first saw the 'Chariot'.
#
# And this was the scene on the day of her first encounter with it.
#
# But there was a difference.
#
# Because the 'Chariot' was a bit bigger and faster than the horse she had been riding before.
#
# "What's this thing looking at me?!"
#
# "It's the beastmaster, Alucard!"
#
#
# ================================================================================
#
# ![title](img/tree.png)
#
# Model prompt >>> our landmark tree in town was about to be destroyed and cleared for a new mall .so we decided to take the day to go out and enjoy its beauty .to see the final glimpse of the roots , extending out into the depths of the hill .and its magnificent trunk , larger than life itself .one last picture of its beauty so we could capture it forever .
#
# ======================================== SAMPLE 1 ========================================
#
# and the most memorable moment , although for the time being its just a small slice of the beautiful tree will always be with us, we will cherish it far past its last moments.<|endoftext|>SOUTH BRUNSWICK, NJ — It has become common knowledge that The City of Brotherly Love is a sex-addicted, cocaine-dealing, porn-loving and whore-loving cesspool of public intoxication and debauchery.
#
# But the City of Brotherly Love is NOT unique
#
# ======================================== SAMPLE 2 ========================================
#
# our goal was to capture one moment of the history of the tree and its stories .this was the perfect way to celebrate how it had changed the lives of so many and how much it meant to them .
#
# We knew there would be a lot of photos to take during this trip, so we were nervous at first .but we had a wonderful team of photographers and we needed them to capture as many pictures as possible .so we went out in the afternoon , in the beautiful summer sun , and
#
#
#
# ================================================================================
#
# ![title](img/monument.png)
#
# Model prompt >>> our trip to location last year was filled with beauty . sculptures could be found everywhere we went .the architecture was old and interesting .since it was spring , beautiful flowers lined the streets . this pink bloom was particularly lovely .we went to a museum and saw this odd collection of hanging faces !i 'd have to say my favorite part of the trip would have to be the food though . we ca n't wait to go back again !
#
# ======================================== SAMPLE 1 ========================================
#
# <|endoftext|>The following is a guest post from Michael Seifert, a professor of Sociology at Harvard University and former associate dean of Harvard Business School, who works with students in the Behavioral Science Laboratory of the Harvard-affiliated Harvard Graduate School of Management.
#
# The notion of individual rights is central to the liberal democratic tradition. It is also central to the American legal tradition, where individual rights are often recognized as the core foundation of constitutional government. In the United States, this philosophy has led it to
#
# ======================================== SAMPLE 2 ========================================
#
# <|endoftext|>Visa fraud is a problem everywhere, from South America to Asia. The problem is particularly acute in developing countries and has caused a steady increase in the number of fraudulent visa applications within the past 2 years, according to the Department of Homeland Security's Visa Fraud Detection Program (VDFP).
#
# Visa fraud is the crime of forging or misappropriating credentials that are used to obtain foreign travel permits. Often, the fraud is perpetrated by people who have very little knowledge about the underlying requirements
#
#
#
# ================================================================================
#
# ![title](img/city.png)
#
# Model prompt >>> the city in 1940 decided to build a water dam .over 100 's of construction trucks .the city dam was used to generate power to the city .the construction workers began leveling the ground for the water dam .water pumps were used to control the water flow of the dam .
#
# ======================================== SAMPLE 1 ========================================
#
# wheat was used to make the ground smooth .the water pumped from the bottom of the dam was used to produce electricity .this water was used to power water pumps for the city .the city water was used to irrigate the surrounding area .the city water was used to irrigate the surrounding area .the water was used to irrigate the surrounding area .the city water was used to irrigate the surrounding area .the city water was used to irrigate the surrounding area .the city water was
#
# ======================================== SAMPLE 2 ========================================
#
# as the water was being pumped ,the workers were cut down to the lake level ,the workers were used to put out the fire .the workers were cut down to the lake level .
#
# The workers were taken out of the city to work the nearby dam .the workers were taken out of the city to work the nearby dam .
#
# The city would later say they did not use water to generate electricity for the dam .the city would later say they did not use water to generate electricity for
#
#
#
# ================================================================================
#
# Model prompt >>> my father visited location for the summer .he visited a small temple .he encountered many great people on his visit .a few of the individuals he took pictures of were camera shy .inside the temple you could see the beautiful hand carved and painted murals .
#
# ======================================== SAMPLE 1 ========================================
#
# the murals were beautiful and could have been any age .the temple was very small ,if you can take a picture of the murals ,you will find them in a number of other temples in America .it was a beautiful place .when he left the temple he told me he felt so good he could not put it away .he had been so touched by the temple that he would stay and view and explore all the murals .the temple was in a beautiful locale ,they had amazing views
#
# ======================================== SAMPLE 2 ========================================
#
#
# he wanted to learn more about the murals and the artifacts that had been made there .the temple was full of artifacts from every culture of mankind .i saw these wonderful artifacts and they reminded me in no uncertain terms of my own heritage .i feel very proud of my ancestors and their accomplishments and how they've interacted with the world.
#
# I had the opportunity to visit a few of the temples that i visited and i have to say that even though i did not have the opportunity to take pictures
#
#
# ================================================================================
#
# Model prompt >>> the couple took a picture .his wife was pregnant .they took a silly picture .they later went on a hike .they got a picture of her behind a mountain .
#
# ======================================== SAMPLE 1 ========================================
#
# she was born .she is named Julia .she lives in Alabama .they have 3 sons .they have an 8 year old daughter named Julia .(Julia was born with birth defect) .they moved to Arizona .they had a baby girl named Julia .she also has a birth defect .she is named Julia .she lives in Arizona .and she is a registered nurse .her mother is a registered nurse .she is working as a registered nurse .her father is a registered nurse .she attended
#
# ======================================== SAMPLE 2 ========================================
# they got a picture of them all together .
#
# They ate at a place they used to go to .they ate at a hotel they used to stay at .they ate at a restaurant they used to go to .they ate at a restaurant they used to stay at .they ate at a restaurant they used to stay at .they ate at a restaurant they used to stay at .they ate at a restaurant they used to stay at .
#
# They were running .they were making a plan .
#
#
#
# ================================================================================
#
# Model prompt >>> the family celebrated our 2 year old birthday .our 2 year old is a [female] baby .we rented a fun house to jump in .our eldest daughter did n't seem to get tired .the loving man in our lives reminded us of the importance of family .
#
# ======================================== SAMPLE 1 ========================================
#
# our oldest son got sick and died on our 2 year old baby's 1st birthday .our 2 year old stayed with her dad and my daughter and still was alive .our youngest son got sick on his 1st birthday .sometime in the summer of 2013 , he stopped breathing and died .we have a son .we have a daughter .we still have no idea what to do with him .we are very concerned for his family .we are still caring for him .he was born on September
#
# ======================================== SAMPLE 2 ========================================
#
# he asked us to bring our beautiful daughter my best friend ,and it was a surprise to us because .she was not expecting this .she looked happy to see us .and we were so happy .we loved our daughter so much . We also saw her walking around ,and she looked so cute .we were very excited .the mother and daughter were so happy .and we loved her .we loved .and loved .and loved .and loved .and loved .and loved .and love .and
#
# ================================================================================

# %% [markdown]
# ### BLEU Score for some of the examples
#
# I know that BLEU score is should be between individual sentences but the results is not a direct mapping or translation from the refernce so I took the whole text and compared them together.

# %%
reference = "Delicious Thai dishes started with some crispy chicken. pad thai is always one of my favorites. this dish featured sprouts and veggies. this one was crispy and very tasty. this was a simple dish with veggies sliced thin. my favorite!"
hypothesis = "I'm always looking for ways to improve my Thai food. My favorite is Pad Thai. It's usually one of my favorites when it comes to dishes. If you are looking for some of the best Thai food in LA with great results, try this place! It's cheap, you can eat there in about 3 minutes and they have some of the best Thai food in the city. They serve Thai food in a casual atmosphere with no wait. I can't wait to try all their restaurants"

# %%
import nltk

BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)
print (BLEUscore)
# Out:
# 0.2780042818829936

# %%
reference2 = "our landmark tree in town was about to be destroyed and cleared for a new mall .so we decided to take the day to go out and enjoy its beauty .to see the final glimpse of the roots , extending out into the depths of the hill .and its magnificent trunk , larger than life itself .one last picture of its beauty so we could capture it forever ."
hypothesis2 = "our goal was to capture one moment of the history of the tree and its stories .this was the perfect way to celebrate how it had changed the lives of so many and how much it meant to them .We knew there would be a lot of photos to take during this trip, so we were nervous at first .but we had a wonderful team of photographers and we needed them to capture as many pictures as possible .so we went out in the afternoon , in the beautiful summer sun , and"
BLEUscore2 = nltk.translate.bleu_score.sentence_bleu([reference2], hypothesis2)
print (BLEUscore2)
# Out:
# 0.4025947828587787

# %%
reference3 = "our trip to location last year was filled with beauty . sculptures could be found everywhere we went .the architecture was old and interesting .since it was spring , beautiful flowers lined the streets . this pink bloom was particularly lovely .we went to a museum and saw this odd collection of hanging faces !i 'd have to say my favorite part of the trip would have to be the food though . we ca n't wait to go back again !"
hypothesis3 = "The following is a guest post from Michael Seifert, a professor of Sociology at Harvard University and former associate dean of Harvard Business School, who works with students in the Behavioral Science Laboratory of the Harvard-affiliated Harvard Graduate School of Management.The notion of individual rights is central to the liberal democratic tradition. It is also central to the American legal tradition, where individual rights are often recognized as the core foundation of constitutional government. In the United States, this philosophy has led it to"
BLEUscore3 = nltk.translate.bleu_score.sentence_bleu([reference3], hypothesis3)
print (BLEUscore3)
# Out:
# 0.26498934624828197

# %% [markdown]
# ### Reference

# %% [markdown]
# https://openai.com/blog/better-language-models/
#
# GPT-2 Playground Jupyter notebook  https://colab.research.google.com/github/ilopezfr/gpt-2/blob/master/gpt-2-playground_.ipynb
#
# https://github.com/lichengunc/vist_api
